# %% [markdown]
# ## Concepts of Imaging

# %% [markdown]
# Imaging is the proccess of generating an astronomical image from a measurement set

# %% [markdown]
# ## Getting the Data

# %% [markdown]
# This tutorial centers iteself in working with data from combined 7m and 12m interferometric data from ALMA, this data is obtained directly from the data science archive: https://almascience.nrao.edu/aq/

# %% [markdown]
# Explain how to search for a project and download the raw data

# %% [markdown]
# MOve to the First Look at Imaging instructions
