# %% [markdown]
# ## Norma

# %%
from scipy.spatial import distance

# %%
distance.minkowski([0,0], [3,5], p=1)
# Out:
# 8.0

# %%
distance.minkowski([0,0], [3,5], p=2)
# Out:
# 5.830951894845301

# %%
distance.minkowski([0,0], [3,5], p=3)
# Out:
# 5.336803297443889

# %%
distance.minkowski([0,0], [3,5], p=4)
# Out:
# 5.154673657097299

# %% [markdown]
# As p increases the distance between two points differ
#
# <div>
# <img src="attachment:image.png" width= "400" />
# <div>

# %%
distance.minkowski([0,0], [3,5], p= 1)
# Out:
# 8.0
